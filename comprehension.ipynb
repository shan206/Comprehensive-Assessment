# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/91954/Downloads/myexcel.csv.csv')

# %%
df['Height']=np.random.randint(150, 180,size=458)

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     160     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     167     235
# 2   John Holland  Boston Celtics      30       SG   27     168     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     171     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     152     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
Employees_in_each_Team =df.value_counts('Team')
Percentage_Split_Relative = Employees_in_each_Team/Employees_in_each_Team.sum()*100
Percentage_Split_Relative
# Out:
# Team
# New Orleans Pelicans      4.148472
# Memphis Grizzlies         3.930131
# Utah Jazz                 3.493450
# New York Knicks           3.493450
# Milwaukee Bucks           3.493450
# Atlanta Hawks             3.275109
# Toronto Raptors           3.275109
# San Antonio Spurs         3.275109
# Sacramento Kings          3.275109
# Portland Trail Blazers    3.275109
# Phoenix Suns              3.275109
# Philadelphia 76ers        3.275109
# Oklahoma City Thunder     3.275109
# Boston Celtics            3.275109
# Miami Heat                3.275109
# Los Angeles Lakers        3.275109
# Los Angeles Clippers      3.275109
# Indiana Pacers            3.275109
# Houston Rockets           3.275109
# Golden State Warriors     3.275109
# Detroit Pistons           3.275109
# Denver Nuggets            3.275109
# Dallas Mavericks          3.275109
# Cleveland Cavaliers       3.275109
# Chicago Bulls             3.275109
# Charlotte Hornets         3.275109
# ...

# %%
counts = df['Team'].value_counts()
counts.plot(kind='bar')
plt.xlabel('Team')
plt.ylabel('No of Players')
plt.title('Distribution of employyes across various teams')
plt.show()

# %%
Empolyees_Sort_Position = df.sort_values(by="Position",ascending=False)

# %%
Empolyees_Sort_Position.value_counts('Position')
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# dtype: int64

# %%
Empolyees_Sort_Position.value_counts('Position').plot(kind="pie",autopct='%1.1f%%')
plt.title('Segregate employees based on their positions within the company\n\n\n\n')
plt.legend() # shows label
plt.show()

# %%
Predominant_Age = df.value_counts('Age')
Predominant_Age
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 30    31
# 28    31
# 29    28
# 22    26
# 31    22
# 21    19
# 20    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 38     4
# 37     4
# 40     3
# 39     2
# 19     2
# dtype: int64

# %%
Predominant_Age.plot(kind='bar')
plt.xlabel('Age of Players')
plt.ylabel('No of Players')
plt.title('Age group among employees')
plt.show()

# %%
salary_exp_by_team = df.groupby(['Team'])[['Salary']].sum()

# %%
Team_highest_Exp =salary_exp_by_team['Salary'].sort_values(ascending = False)
Team_highest_Exp .head()
# Out:
# Team
# Cleveland Cavaliers      106988689.0
# Los Angeles Clippers      94854640.0
# Oklahoma City Thunder     93765298.0
# Golden State Warriors     88868997.0
# Chicago Bulls             86783378.0
# Name: Salary, dtype: float64

# %%
Team_highest_Exp.plot(kind='bar')
plt.xlabel('Salary')
plt.ylabel('Team')
plt.show()

# %%
plt.figure(figsize=(8,5),dpi=100)
sns.scatterplot(y="Salary",x="Age",data=df)
plt.xlabel("Age")
plt.ylabel("Salary")
#show
plt.show()

# %%
## Data Story

### Insights:

1. **Team Distribution**: The bar chart and pie chart show the distribution and percentage split of employees across various teams. The data reveals which teams have the highest and lowest number of employees.

2. **Position Distribution**: The bar chart for positions illustrates how employees are distributed across different roles within the company. This helps in understanding the workforce structure.

3. **Age Groups**: The age distribution bar chart highlights the predominant age group among employees, providing insights into the company's demographic.

4. **Salary Expenditure**: Analysis of salary expenditure by team and position shows which teams and roles have the highest financial impact. This can be crucial for budget allocation and financial planning.

5. **Age-Salary Correlation**: The scatter plot and correlation coefficient indicate whether there's a relationship between age and salary. Understanding this correlation can help in making informed decisions regarding salary structures and career progression.

### Key Trends and Patterns:
- The most populated teams and positions can help identify critical areas within the company.
- Salary distribution insights can assist in optimizing payroll and budgeting.
- Understanding the predominant age group helps in tailoring employee engagement and retention strategies.
- Correlation between age and salary can guide policies on promotions and compensation.

By completing this analysis, we've gained a comprehensive understanding of the employee distribution, salary expenditures, and potential correlations within ABC company. These insights are crucial for strategic decision-making and workforce management.
